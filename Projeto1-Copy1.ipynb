# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Isadora Stigliani Dalberto

# %% [markdown]
# ## Pergunta (s) a ser respondida

# %% [markdown]
# Os países que entraram no SADC (Comunidade para o Desenvolvimento da África Austral) em 1992 tiveram um aumento no seu PIB superior aos países da África que não entraram?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# O World Banana Forum promove o contato entre entidades envolvidas na cadeia produtiva das bananas. É razoável esperar que países que fazem parte do WBF tenham acesso a mais oportunidades comerciais e também vejam as barreiras de importação a suas bananas diminuirem.
#
# Para tirar nota acima de B é preciso indicar uma referência (estudo, artigo científico ou estudo) que embase dizer que a hipótese é crível. Use os [recursos de busca da biblioteca](https://www.insper.edu.br/biblioteca-telles/recursos-de-busca/)

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# Insira links para o site de download das bases de dados. Indique quais as variáveis de interesse vêm de cada uma
#
# https://www.gapminder.org/tools/#$state$time$value=2017&delay:100;&marker$select@$country=nga;&$country=ner;&$country=nam;&$country=mwi;&$country=mus;&$country=mrt;&$country=mar;&$country=lso;&$country=lby;&$country=mdg;&$country=moz;&$country=lbr;&$country=zwe;&$country=uga;&$country=tza;&$country=tun;&$country=zmb;&$country=zaf;&$country=tgo;&$country=sle;&$country=sen;&$country=sdn;&$country=rwa;&$country=tcd;&$country=syc;&$country=swz;&$country=stp;&$country=ssd;&$country=cmr;&$country=civ;&$country=caf;&$country=bwa;&$country=cod;&$country=cog;&$country=dji;&$country=cpv;&$country=com;&$country=ago;&$country=bfa;&$country=ben;&$country=ken;&$country=eth;&$country=eri;&$country=egy;&$country=gab;&$country=gnq;&$country=gnb;&$country=gmb;&$country=gin;&$country=gha;&$country=dza;;&axis_x$which=total_gdp_us_inflation_adjusted&scaleType=genericLog&spaceRef:null;;;&ui$sidebarCollapse:true;&chart-type=barrank
#
# https://www.gapminder.org/data/

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# Insira abaixo uma análise de dados tratada para ter maior clareza.
#
# Lembre-se de que, além deste arquivo principal, você precisa entregar um ou mais *notebooks* mais brutos com todas as tentativas que fez e que não deram certo .
#
# **Não inclua dados ou gráficos sem motivação nem interpretação** - sempre que fizer uma análise, plot ou tablea, diga qual sua intenção. Logo após a apresentação diga qual conclusão específica ou interpretação você tira daquela análise

# %% [markdown]
# **Pergunta: Os países que entraram no SADC (Comunidade para o Desenvolvimento da África Austral) em 1992 tiveram um aumento no seu PIB superior aos países da África que não entraram?**
#
# Anos de interesse:
#
#                    de 1971 até 1991 - 20 anos antes de existir o SADC
#
#                    de 1992 até 2010 - 20 anos após o SADC existir
#
# **Hipótese: Os países que entraram na SADC tiveram seu PIB elevado pois, por ser uma organização que visa o crescimento econômico dos países participantes, há uma maior exportação e melhoria na economia do país como um todo.** -- OLHAR DENOVO ESSA HIPOTESE!

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\dorad\OneDrive\Documentos\Insper\2 Semestre\2.CienDados\Projeto1

# %%
dados = pd.read_excel('total_gdp_us_inflation_adjusted.xlsx')

# %%
dados_indice = dados.set_index("country")

# %%
# dimensão da base de dados: (número de linhas, número de colunas)
#dados.shape

# %%
#Países pertencentes ao Bloco SADC (áfrica austral)
af_aus = ["Angola", "South Africa", "Botswana", "Congo, Dem. Rep.", "Lesotho", "Madagascar", "Malawi", "Mauritius", "Mozambique", "Namibia", "Swaziland", "Tanzania", "Zambia", "Zimbabwe"]

# %%
dados_indice.loc[:, "AF_AUS"] = 0      #criar uma coluna chamada AF_AUS e falar que todos os países são 0

# %%
dados_indice.loc[af_aus,"AF_AUS"]=1      #falar que todos os países da lista af_aus recebem o valor de 1 na coluna AF_AUS

# %%
dados_af_aus = dados_indice.loc[af_aus]
#dados_af_aus      #imprime todos os paises que sao do SADC

# %%
dados_indice.AF_AUS.value_counts()      #conta os paises que sao da SADC
# Out:
# 0    176
# 1     14
# Name: AF_AUS, dtype: int64

# %%
#Paises da áfrica que não pertencem ao SADC
af_nao_aus = ["Benin", "Burkina Faso", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Congo, Rep.", "Djibouti", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Liberia", "Mali", "Niger", "Nigeria", "Rwanda", "Senegal", "Seychelles", "Sierra Leone", "Sudan", "Togo", "Uganda" ]

# %%
dados_indice.loc[:, "AF_NAO_AUS"] = 0

# %%
dados_indice.loc[af_nao_aus,"AF_NAO_AUS"]=1

# %%
dados_af_nao_aus = dados_indice.loc[af_nao_aus]
#dados_af_nao_aus      #imprime todos os paises que sao da africa mas nao sao da SADC

# %%
dados_indice.AF_NAO_AUS.value_counts()       #conta os paises que são da áfrica mas não sao da SADC
# Out:
# 0    163
# 1     27
# Name: AF_NAO_AUS, dtype: int64

# %%
transpor = dados_indice.transpose()

# %%
transpor_quant = transpor[:-2]

# %%
africa_anos1 = transpor_quant.loc[(transpor_quant.index>1970) & (transpor_quant.index<1992),:].transpose()
africa_anos1.sum().sum()
# Out:
# 556741448000000.0

# %%
africa_anos2 = transpor_quant.loc[(transpor_quant.index>1991) & (transpor_quant.index<2013),:].transpose()
africa_anos2.sum().sum()
# Out:
# 1104816614600000.0

# %%
# africa_anos1

# %%
# dados_indice.loc[af_aus]

# %%
 # dados_indice.loc[af_nao_aus]

# %%
africa = af_aus + af_nao_aus

# %%
dados_africa = africa_anos1.loc[africa]
dados_africa
# Out:
#                                   1971          1972          1973  \
# country
# Angola                             NaN           NaN           NaN
# South Africa              1.440000e+11  1.460000e+11  1.530000e+11
# Botswana                  5.880000e+08  7.430000e+08  9.020000e+08
# Congo, Dem. Rep.          2.260000e+10  2.270000e+10  2.450000e+10
# Lesotho                   3.780000e+08  3.770000e+08  4.770000e+08
# Madagascar                5.100000e+09  5.040000e+09  4.910000e+09
# Malawi                    1.600000e+09  1.700000e+09  1.740000e+09
# Mauritius                          NaN           NaN           NaN
# Mozambique                         NaN           NaN           NaN
# Namibia                            NaN           NaN           NaN
# Swaziland                 6.010000e+08  6.340000e+08  6.910000e+08
# Tanzania                           NaN           NaN           NaN
# Zambia                    6.600000e+09  7.210000e+09  7.140000e+09
# Zimbabwe                  6.730000e+09  7.290000e+09  7.480000e+09
#
#                                   1980      ...               1982  \
# country                                     ...
# Angola                    2.080000e+10      ...       1.990000e+10
# South Africa              1.920000e+11      ...       2.010000e+11
# Botswana                  1.890000e+09      ...       2.320000e+09
# Congo, Dem. Rep.          2.230000e+10      ...       2.270000e+10
# Lesotho                   7.330000e+08      ...       7.710000e+08
# Madagascar                5.420000e+09      ...       4.810000e+09
# Malawi                    2.510000e+09      ...       2.440000e+09
# Mauritius                 2.190000e+09      ...       2.440000e+09
# Mozambique                2.260000e+09      ...       2.210000e+09
# Namibia                   4.410000e+09      ...       4.440000e+09
# Swaziland                 9.670000e+08      ...       1.120000e+09
# Tanzania                           NaN      ...                NaN
# Zambia                    7.560000e+09      ...       7.800000e+09
# Zimbabwe                  8.420000e+09      ...       9.720000e+09
# Benin                     2.210000e+09      ...       2.480000e+09
# Burkina Faso              2.130000e+09      ...       2.430000e+09
# Burundi                   1.150000e+09      ...       1.280000e+09
# Cameroon                  1.140000e+10      ...       1.430000e+10
# Cape Verde                1.930000e+08      ...       2.150000e+08
# Central African Republic  1.240000e+09      ...       1.320000e+09
# Chad                      1.850000e+09      ...       1.970000e+09
# Congo, Rep.               4.140000e+09      ...       6.010000e+09
# Djibouti                           NaN      ...                NaN
# Eritrea                            NaN      ...                NaN
# Ethiopia                           NaN      ...       8.300000e+09
# Gabon                     8.850000e+09      ...       9.010000e+09
# Gambia                    3.310000e+08      ...       3.400000e+08
# Ghana                     9.740000e+09      ...       8.740000e+09
# Guinea                             NaN      ...                NaN
# Guinea-Bissau             3.830000e+08      ...       4.710000e+08
# Liberia                   2.760000e+09      ...       2.630000e+09
# Mali                      3.170000e+09      ...       2.980000e+09
# Niger                     3.100000e+09      ...       3.170000e+09
# Nigeria                   1.440000e+11      ...       1.240000e+11
# Rwanda                    2.130000e+09      ...       2.290000e+09
# Senegal                   4.960000e+09      ...       5.620000e+09
# Seychelles                3.870000e+08      ...       3.510000e+08
# Sierra Leone              1.640000e+09      ...       1.770000e+09
# Sudan                     1.550000e+10      ...       1.770000e+10
# Togo                      1.860000e+09      ...       1.730000e+09
# Uganda                             NaN      ...       4.040000e+09
#
#                                   1983          1984          1985  \
# country
# Angola                    2.080000e+10  2.200000e+10  2.280000e+10
# South Africa              1.980000e+11  2.080000e+11  2.050000e+11
# Botswana                  2.620000e+09  2.850000e+09  3.050000e+09
# Congo, Dem. Rep.          2.300000e+10  2.430000e+10  2.440000e+10
# Lesotho                   7.860000e+08  8.290000e+08  8.510000e+08
# Madagascar                4.850000e+09  4.930000e+09  4.990000e+09
# Malawi                    2.530000e+09  2.660000e+09  2.780000e+09
# Mauritius                 2.450000e+09  2.570000e+09  2.750000e+09
# Mozambique                1.860000e+09  1.740000e+09  1.760000e+09
# Namibia                   4.360000e+09  4.350000e+09  4.370000e+09
# Swaziland                 1.130000e+09  1.200000e+09  1.250000e+09
# Tanzania                           NaN           NaN           NaN
# Zambia                    7.650000e+09  7.620000e+09  7.750000e+09
# Zimbabwe                  9.880000e+09  9.690000e+09  1.040000e+10
# Mozambique                4.230000e+09  4.560000e+09  4.640000e+09
# Namibia                   6.650000e+09  6.880000e+09  7.120000e+09
# Swaziland                 2.990000e+09  3.080000e+09  3.130000e+09
# Tanzania                  1.500000e+10  1.570000e+10  1.650000e+10
# Zambia                    9.090000e+09  9.510000e+09  9.880000e+09
# Zimbabwe                  1.600000e+10  1.590000e+10  1.540000e+10
# Benin                     4.270000e+09  4.500000e+09  4.770000e+09
# Burkina Faso              4.610000e+09  4.960000e+09  5.050000e+09
# Burundi                   1.490000e+09  1.470000e+09  1.460000e+09
# Cameroon                  1.650000e+10  1.720000e+10  1.780000e+10
# Cape Verde                7.460000e+08  8.300000e+08  9.480000e+08
# Central African Republic  1.530000e+09  1.590000e+09  1.550000e+09
# Chad                      3.920000e+09  3.890000e+09  3.860000e+09
# Congo, Rep.               7.280000e+09  7.090000e+09  7.630000e+09
# Djibouti                           NaN           NaN           NaN
# Eritrea                   2.000000e+09  2.000000e+09  1.940000e+09
# Ethiopia                  1.170000e+10  1.230000e+10  1.310000e+10
# Gabon                     1.400000e+10  1.270000e+10  1.250000e+10
# Gambia                    5.820000e+08  6.190000e+08  6.530000e+08
# Ghana                     1.700000e+10  1.770000e+10  1.840000e+10
# Guinea                    4.840000e+09  5.030000e+09  5.150000e+09
# Guinea-Bissau             6.210000e+08  6.280000e+08  6.620000e+08
# Liberia                   7.230000e+08  8.800000e+08  1.130000e+09
# Mali                      5.750000e+09  6.080000e+09  6.070000e+09
# Niger                     3.730000e+09  3.710000e+09  3.660000e+09
# Nigeria                   1.490000e+11  1.500000e+11  1.570000e+11
# Rwanda                    2.320000e+09  2.420000e+09  2.630000e+09
# Senegal                   7.900000e+09  8.400000e+09  8.670000e+09
# Seychelles                7.680000e+08  7.820000e+08  7.940000e+08
# Sierra Leone              1.330000e+09  1.300000e+09  1.390000e+09
# Sudan                     3.110000e+10  3.200000e+10  3.410000e+10
# Togo                      2.520000e+09  2.580000e+09  2.560000e+09
# Uganda                    8.890000e+09  9.610000e+09  9.910000e+09
#
#                                   2001      ...               2003  \
# country                                     ...
# Angola                    2.950000e+10      ...       3.500000e+10
# South Africa              2.740000e+11      ...       2.930000e+11
# Botswana                  8.580000e+09      ...       9.530000e+09
# Congo, Dem. Rep.          1.340000e+10      ...       1.450000e+10
# Lesotho                   1.700000e+09      ...       1.790000e+09
# Madagascar                7.190000e+09      ...       6.890000e+09
# Malawi                    4.160000e+09      ...       4.470000e+09
# Mauritius                 6.770000e+09      ...       7.160000e+09
# Mozambique                5.220000e+09      ...       6.050000e+09
# Namibia                   7.200000e+09      ...       7.860000e+09
# Swaziland                 3.170000e+09      ...       3.430000e+09
# Tanzania                  1.750000e+10      ...       2.000000e+10
# Zambia                    1.040000e+10      ...       1.160000e+10
# Zimbabwe                  1.560000e+10      ...       1.180000e+10
# Benin                     5.020000e+09      ...       5.430000e+09
# Burkina Faso              5.380000e+09      ...       6.050000e+09
# Burundi                   1.490000e+09      ...       1.540000e+09
# Cameroon                  1.850000e+10      ...       2.020000e+10
# Cape Verde                9.700000e+08      ...       1.060000e+09
# Central African Republic  1.620000e+09      ...       1.580000e+09
# Chad                      4.310000e+09      ...       5.360000e+09
# Congo, Rep.               7.920000e+09      ...       8.350000e+09
# Djibouti                           NaN      ...                NaN
# Eritrea                   2.110000e+09      ...       2.110000e+09
# Ethiopia                  1.420000e+10      ...       1.410000e+10
# Gabon                     1.270000e+10      ...       1.300000e+10
# Gambia                    6.910000e+08      ...       7.140000e+08
# Ghana                     1.910000e+10      ...       2.100000e+10
# Guinea                    5.340000e+09      ...       5.690000e+09
# Guinea-Bissau             6.760000e+08      ...       6.730000e+08
# Liberia                   1.170000e+09      ...       8.450000e+08
# Mali                      7.010000e+09      ...       7.880000e+09
# Niger                     3.920000e+09      ...       4.250000e+09
# Nigeria                   1.640000e+11      ...       1.880000e+11
# Rwanda                    2.850000e+09      ...       3.300000e+09
# Senegal                   9.070000e+09      ...       9.730000e+09
# Seychelles                7.760000e+08      ...       7.390000e+08
# Sierra Leone              1.300000e+09      ...       1.790000e+09
# Sudan                     3.630000e+10      ...       4.160000e+10
# Togo                      2.520000e+09      ...       2.620000e+09
# Uganda                    1.040000e+10      ...       1.210000e+10
#
#                                   2004          2005          2006  \
# country
# Angola                    3.860000e+10  4.670000e+10  5.560000e+10
# South Africa              3.060000e+11  3.220000e+11  3.400000e+11
# Botswana                  9.790000e+09  1.020000e+10  1.110000e+10
# Congo, Dem. Rep.          1.550000e+10  1.650000e+10  1.730000e+10
# Lesotho                   1.820000e+09  1.890000e+09  1.970000e+09
# Madagascar                7.260000e+09  7.590000e+09  7.970000e+09
# Malawi                    4.710000e+09  4.870000e+09  5.100000e+09
# Mauritius                 7.580000e+09  7.670000e+09  8.330000e+09
# Mozambique                6.530000e+09  7.100000e+09  7.790000e+09
# Namibia                   8.830000e+09  9.050000e+09  9.690000e+09
# Swaziland                 3.560000e+09  3.770000e+09  4.000000e+09
# Tanzania                  2.160000e+10  2.340000e+10  2.450000e+10
# Zambia                    1.240000e+10  1.340000e+10  1.440000e+10
# Zimbabwe                  1.110000e+10  1.050000e+10  1.010000e+10
# Benin                     5.680000e+09  5.770000e+09  6.000000e+09
# Burkina Faso              6.320000e+09  6.870000e+09  7.300000e+09
# Burundi                   1.610000e+09  1.630000e+09  1.710000e+09
# Cameroon                  2.160000e+10  2.200000e+10  2.280000e+10
# Cape Verde                1.170000e+09  1.250000e+09  1.350000e+09
# Central African Republic  1.680000e+09  1.690000e+09  1.770000e+09
# Chad                      7.170000e+09  8.410000e+09  8.460000e+09
# Congo, Rep.               8.640000e+09  9.310000e+09  9.890000e+09
# Djibouti                           NaN           NaN           NaN
# Eritrea                   2.150000e+09  2.200000e+09  2.180000e+09
# Ethiopia                  1.600000e+10  1.790000e+10  1.980000e+10
# Gabon                     1.310000e+10  1.340000e+10  1.310000e+10
# Gambia                    7.650000e+08  7.580000e+08  7.660000e+08
# Ghana                     2.220000e+10  2.350000e+10  2.500000e+10
# Guinea                    5.820000e+09  5.990000e+09  6.060000e+09
# Guinea-Bissau             6.920000e+08  7.210000e+08  7.380000e+08
# Sudan                     5.700000e+10  6.140000e+10  6.340000e+10
# Togo                      2.880000e+09  2.950000e+09  3.050000e+09
# Uganda                    1.650000e+10  1.790000e+10  1.910000e+10
#
#                                   2010          2011          2012
# country
# Angola                    8.250000e+10  8.570000e+10  9.020000e+10
# South Africa              3.750000e+11  3.880000e+11  3.960000e+11
# Botswana                  1.280000e+10  1.360000e+10  1.420000e+10
# Congo, Dem. Rep.          2.160000e+10  2.300000e+10  2.470000e+10
# Lesotho                   2.390000e+09  2.550000e+09  2.700000e+09
# Madagascar                8.730000e+09  8.860000e+09  9.130000e+09
# Malawi                    6.960000e+09  7.300000e+09  7.440000e+09
# Mauritius                 1.000000e+10  1.040000e+10  1.080000e+10
# Mozambique                1.020000e+10  1.090000e+10  1.170000e+10
# Namibia                   1.130000e+10  1.190000e+10  1.250000e+10
# Swaziland                 4.440000e+09  4.540000e+09  4.750000e+09
# Tanzania                  3.140000e+10  3.390000e+10  3.560000e+10
# Zambia                    2.030000e+10  2.140000e+10  2.300000e+10
# Zimbabwe                  1.010000e+10  1.170000e+10  1.340000e+10
# Benin                     6.970000e+09  7.180000e+09  7.520000e+09
# Burkina Faso              8.980000e+09  9.580000e+09  1.020000e+10
# Burundi                   2.030000e+09  2.110000e+09  2.200000e+09
# Cameroon                  2.610000e+10  2.720000e+10  2.850000e+10
# Cape Verde                1.660000e+09  1.730000e+09  1.750000e+09
# Central African Republic  1.990000e+09  2.050000e+09  2.140000e+09
# Chad                      1.070000e+10  1.070000e+10  1.160000e+10
# Congo, Rep.               1.200000e+10  1.240000e+10  1.290000e+10
# Djibouti                  1.130000e+09           NaN           NaN
# Eritrea                   2.120000e+09  2.300000e+09           NaN
# Ethiopia                  2.990000e+10  3.330000e+10  3.620000e+10
# Gabon                     1.440000e+10  1.540000e+10  1.620000e+10
# Gambia                    9.520000e+08  9.110000e+08  9.620000e+08
# Ghana                     3.220000e+10  3.670000e+10  4.010000e+10
# Guinea                    6.990000e+09  7.380000e+09  7.820000e+09
# Guinea-Bissau             8.510000e+08  9.190000e+08  9.040000e+08
# Liberia                   1.290000e+09  1.400000e+09  1.510000e+09
# Mali                      1.070000e+10  1.100000e+10  1.090000e+10
# Niger                     5.720000e+09  5.850000e+09  6.540000e+09
# Nigeria                   3.690000e+11  3.870000e+11  4.040000e+11
# Rwanda                    5.770000e+09  6.240000e+09  6.780000e+09
# Senegal                   1.290000e+10  1.320000e+10  1.380000e+10
# Seychelles                9.700000e+08  1.050000e+09  1.060000e+09
# Sierra Leone              2.580000e+09  2.740000e+09  3.160000e+09
# Sudan                     6.560000e+10  6.430000e+10  6.470000e+10
# Togo                      3.170000e+09  3.330000e+09  3.490000e+09
# Uganda                    2.020000e+10  2.210000e+10  2.290000e+10
#
# [41 rows x 21 columns]

# %%
print(len(transpor_quant))  #Descobrir o tamanho da função transpor pra conseguir plotar o gráfico
# Out:
# 58

# %%
#   CÓDIGO EM CONSTRUÇÃO   

soma_sadc = dados_af_aus.sum()  #somas todos os paises POR ANO que sao da SADC
soma_nao_sadc = dados_af_nao_aus.sum()   #somar todos os paises POR ANO que não sao da SADC
#plotar um gráfico de comparação de PIB (x) por ANO (y) comparando o SADC com o não SADC -- (plotar os 2 no mesmo gráfico e
# usar a função plt.legend com os devidos labels)

plt.plot(transpor_quant, soma_sadc , label="paises da SADC") #erro em como plotar a soma por ano dos paises SADC
plt.plot(transpor_quant, soma_nao_sadc , label="nao SADC") #erro em como plotar a soma por ano dos paises nao SADC
plt.xabel("anos")
plt.ylabel("GDP")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-089ce0e1cc8e> in <module>
#       6 # usar a função plt.legend com os devidos labels)
#       7
# ----> 8 plt.plot(transpor_quant, soma_sadc , label="paises da SADC") #erro em como plotar a soma por ano dos paises SADC
#       9 plt.plot(transpor_quant, soma_nao_sadc , label="nao SADC") #erro em como plotar a soma por ano dos paises nao SADC
#      10 plt.xabel("anos")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (58, 190) and (59,)

# %%
dados_af_aus1 = africa_anos1.loc[af_aus]
print('PIB total dos países da SADC de 1971 à 1991')
dados_af_aus1.sum().sum() / 14
# Out:
# PIB total dos países da SADC de 1971 à 1991
# 394528142857.1429

# %%
dados_af_aus2 = africa_anos2.loc[af_aus]
print('PIB total dos países da SADC de 1992 à 2012')
dados_af_aus2.sum().sum() / 14
# Out:
# PIB total dos países da SADC de 1992 à 2012
# 679862857142.8572

# %%
print('Diferença por pais entre os intervalos de tempo dos paises da SADC')
(dados_af_aus2.sum().sum() - dados_af_aus1.sum().sum()) / 14
#FAZER EM PORCENTAGEM !!!! (O AUMENTO PERCENTUAL) -- OU FAZER A MÉDIA DE CADA E O AUMENTO PERCENTUAL DA MÉDIA!!!
# Out:
# Diferença por pais entre os intervalos de tempo dos paises da SADC
# 285334714285.7143

# %%
dados_af_nao_aus1 = africa_anos1.loc[af_nao_aus]
print('PIB total dos países da áfrica que não são da SADC de 1971 à 1991')
dados_af_nao_aus1.sum().sum() / 27
# Out:
# PIB total dos países da áfrica que não são da SADC de 1971 à 1991
# 165056629629.62964

# %%
dados_af_nao_aus2 = africa_anos2.loc[af_nao_aus]
print('PIB total dos países da áfrica que não são da SADC de 1992 à 2012')
dados_af_nao_aus2.sum().sum() / 27
# Out:
# PIB total dos países da áfrica que não são da SADC de 1992 à 2012
# 328766962962.96295

# %%
print('Diferenca por pais entre os intervalos de tempo dos paises da áfrica que nao fazem parte da SADC')
(dados_af_nao_aus2.sum().sum() - dados_af_nao_aus1.sum().sum()) / 27
# Out:
# Diferenca por pais entre os intervalos de tempo dos paises da áfrica que nao fazem parte da SADC
# 163710333333.33334

# %%
#OBS: O af_nao_aus tem praticamente o dobro de paises que o af_aus! tem que arranjar um jeito de ser proporcional!
# --- fazer a média? (é eficiente?  / o melhor jeito?)

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Responda à pergunta, argumento da melhor forma possível com base nos dados
